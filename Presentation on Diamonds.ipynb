# %% [markdown]
# # The Diamond Story

# %% [markdown]
# ![diamond_pic.jpg](attachment:diamond_pic.jpg)

# %% [markdown]
# A diamond’s quality is determined by the <h3> _4C’s_ </h3>
#
# __Cut__: Quality of the angles, proportions, facets, and finishing details.
#
# __Color__: How colorless the diamond is.
#
# __Clarity__: How clean the diamond is of inclusions and blemishes.
#
# __Carat__: The weight of the diamond
#
# These four qualities of a diamond are the key components that impact its beauty and structure. The 4C’s interact with each other within the diamond. They dictate how the diamond appears and how high quality it is. As an example, the diamond’s ability to reflect light back to your eyes depends primarily on cut quality but also on color and clarity.
#
# The four diamond characteristics are graded by professionals on a consistent scale, giving you a tool to evaluate diamonds. By reviewing the 4C’s of a particular diamond, you can better determine if the diamond is of high-quality.
#
#
#
# The __GIA__ and the __AGSL__ are the prominent institutions with a sophisticated grading system for evaluating diamond characteristics.

# %% [markdown]
# ![cut,color,clarity.jpg](attachment:cut,color,clarity.jpg)

# %% [markdown]
# __Carat__: The weight of the diamond
#
# These four qualities of a diamond are the key components that impact its beauty and structure. The 4C’s interact with each other within the diamond. They dictate how the diamond appears and how high quality it is. As an example, the diamond’s ability to reflect light back to your eyes depends primarily on cut quality but also on color and clarity.
#
# The four diamond characteristics are graded by professionals on a consistent scale, giving you a tool to evaluate diamonds. By reviewing the 4C’s of a particular diamond, you can better determine if the diamond is of high-quality.
#
# The _GIA_ and the _AGSL_ are the prominent institutions with a sophisticated grading system for evaluating diamond characteristics.

# %% [markdown]
# ![carat.jpg](attachment:carat.jpg)

# %% [markdown]
# ### Polish & Symmetry
# #### Good, Very Good,Ideal, Excellent
# ### Report
# #### GIA:1 & AGSL

# %%
df1
# Out:
#       Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 0             1.10            Ideal     H     SI1     VG       EX    GIA
# 1             0.83            Ideal     H     VS1     ID       ID   AGSL
# 2             0.85            Ideal     H     SI1     EX       EX    GIA
# 3             0.91            Ideal     E     SI1     VG       VG    GIA
# 4             0.83            Ideal     G     SI1     EX       EX    GIA
# ...            ...              ...   ...     ...    ...      ...    ...
# 5995          1.03            Ideal     D     SI1     EX       EX    GIA
# 5996          1.00        Very Good     D     SI1     VG       VG    GIA
# 5997          1.02            Ideal     D     SI1     EX       EX    GIA
# 5998          1.27  Signature-Ideal     G     VS1     EX       EX    GIA
# 5999          2.19            Ideal     E     VS1     EX       EX    GIA
#
#       Price
# 0      5169
# 1      3470
# 2      3183
# 3      4370
# 4      3171
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df1=pd.read_csv(r'C:\Users\user\OneDrive\Amritha\Presentation\diamond.csv')

# %%
round(df1.describe(), 4)
# Out:
#        Carat Weight        Price
# count     6000.0000    6000.0000
# mean         1.3345   11791.5793
# std          0.4757   10184.3501
# min          0.7500    2184.0000
# 25%          1.0000    5150.5000
# 50%          1.1300    7857.0000
# 75%          1.5900   15036.5000
# max          2.9100  101561.0000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Carat Weight  6000 non-null   float64
#  1   Cut           6000 non-null   object
#  2   Color         6000 non-null   object
#  3   Clarity       6000 non-null   object
#  4   Polish        6000 non-null   object
#  5   Symmetry      6000 non-null   object
#  6   Report        6000 non-null   object
#  7   Price         6000 non-null   int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 375.1+ KB

# %%
df1[df1.duplicated()]
# Out:
#       Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 1141          1.01             Good     D     SI1     VG       VG    GIA
# 1423          1.20  Signature-Ideal     G    VVS2     ID       ID   AGSL
# 1507          2.05            Ideal     G     VS1     EX       EX    GIA
# 1525          0.90        Very Good     G     SI1     EX       VG    GIA
# 1539          0.90        Very Good     D     SI1     VG        G    GIA
# ...            ...              ...   ...     ...    ...      ...    ...
# 5874          0.91            Ideal     I     VS2     ID       ID   AGSL
# 5923          1.11            Ideal     I     SI1     EX       EX    GIA
# 5948          1.00        Very Good     E    VVS1     VG        G    GIA
# 5957          2.02            Ideal     G     SI1     EX       EX    GIA
# 5987          1.05            Ideal     G    VVS1     EX       EX    GIA
#
#       Price
# 1141   5541
# 1423  11530
# 1507  28519
# 1525   3752
# 1539   4537
# ...

# %%
df1.drop_duplicates(keep='first',inplace=True)
df1
# Out:
#       Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 0             1.10            Ideal     H     SI1     VG       EX    GIA
# 1             0.83            Ideal     H     VS1     ID       ID   AGSL
# 2             0.85            Ideal     H     SI1     EX       EX    GIA
# 3             0.91            Ideal     E     SI1     VG       VG    GIA
# 4             0.83            Ideal     G     SI1     EX       EX    GIA
# ...            ...              ...   ...     ...    ...      ...    ...
# 5995          1.03            Ideal     D     SI1     EX       EX    GIA
# 5996          1.00        Very Good     D     SI1     VG       VG    GIA
# 5997          1.02            Ideal     D     SI1     EX       EX    GIA
# 5998          1.27  Signature-Ideal     G     VS1     EX       EX    GIA
# 5999          2.19            Ideal     E     VS1     EX       EX    GIA
#
#       Price
# 0      5169
# 1      3470
# 2      3183
# 3      4370
# 4      3171
# ...

# %%
cat_columns = df1.select_dtypes(include = ['object']).columns.tolist()
print(cat_columns)
# Out:
# ['Cut', 'Color', 'Clarity', 'Polish', 'Symmetry', 'Report']

# %%
Cut_rep={'Cut' :['Fair:1','Good :2','Very Good :3','Ideal :4','Signature-Ideal :5']}
print(Cut_rep)
Color_rep={'Color': ['I:1','H:2','G:3','F:4','E:5','D:6']}
print(Color_rep)
Polish_rep={'Polish':['G:1','VG:2','ID:3','EX:4']}
print(Polish_rep)
Symmetry_rep={'Symmetry':['G:1','VG:2','ID:3','EX:4']}
print(Symmetry_rep)
Clarity_rep={'Clarity':['SI1:1','VS2:2','VS1:3','VVS2:4','VVS1:5','IF:6','FL:7']}
print(Clarity_rep)
Report_rep={'Report':['GIA:1','AGSL:2']}
print(Report_rep)

#dfx=pd.DataFrames()

##Price and Carat weight are numbers
# Out:
# {'Cut': ['Fair:1', 'Good :2', 'Very Good :3', 'Ideal :4', 'Signature-Ideal :5']}
# {'Color': ['I:1', 'H:2', 'G:3', 'F:4', 'E:5', 'D:6']}
# {'Polish': ['G:1', 'VG:2', 'ID:3', 'EX:4']}
# {'Symmetry': ['G:1', 'VG:2', 'ID:3', 'EX:4']}
# {'Clarity': ['SI1:1', 'VS2:2', 'VS1:3', 'VVS2:4', 'VVS1:5', 'IF:6', 'FL:7']}
# {'Report': ['GIA:1', 'AGSL:2']}

# %% [markdown]
# ### Converting non numeric values into a numeric represenation for plotting

# %%
ClarityPriority={'SI1':1,'VS2':2,'VS1':3,'VVS2':4,'VVS1':5,'IF':6,'FL':7}
ReportPriority={'GIA':1,'AGSL':2}
CutPriority={'Fair':1,'Good':2,'Very Good':3,'Ideal':4,'Signature-Ideal':5}
ColorPriority={'I':1,'H':2,'G':3,'F':4,'E':5,'D':6}
PolishPriority={'G':1,'VG':2,'ID':3,'EX':4}
SymmetryPriority={'G':1,'VG':2,'ID':3,'EX':4}

# %%
print(df1.head)

df1['Cut Priority']=df1['Cut'].replace(CutPriority)
df1['Color Priority']=df1['Color'].replace(ColorPriority)
df1['Polish Priority']=df1['Polish'].replace(PolishPriority)
df1['Clarity Priority']=df1['Clarity'].replace(ClarityPriority)
df1['Report Priority']=df1['Report'].replace(ReportPriority)
df1['Symmetry Priority']=df1['Symmetry'].replace(SymmetryPriority)

# %%
df1
# Out:
#       Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 0             1.10            Ideal     H     SI1     VG       EX    GIA
# 1             0.83            Ideal     H     VS1     ID       ID   AGSL
# 2             0.85            Ideal     H     SI1     EX       EX    GIA
# 3             0.91            Ideal     E     SI1     VG       VG    GIA
# 4             0.83            Ideal     G     SI1     EX       EX    GIA
# ...            ...              ...   ...     ...    ...      ...    ...
# 5995          1.03            Ideal     D     SI1     EX       EX    GIA
# 5996          1.00        Very Good     D     SI1     VG       VG    GIA
# 5997          1.02            Ideal     D     SI1     EX       EX    GIA
# 5998          1.27  Signature-Ideal     G     VS1     EX       EX    GIA
# 5999          2.19            Ideal     E     VS1     EX       EX    GIA
#
#       Price  Cut Priority  Color Priority  Polish Priority  Clarity Priority  \
# ...

# %%
plt.figure(figsize=(20,10), dpi=150)
plt.scatter(df1['Carat Weight'],df1['Price'],color='r',alpha=0.5)
plt.title("Carat weight Vs Price")
plt.xlabel('Carat Weight')
plt.ylabel('Price')
plt.show()

# %%
# {'Polish': ['G:1', 'VG:2', 'ID:3', 'EX:4']}
# {'Symmetry': ['G:1', 'VG:2', 'ID:3', 'EX:4']}
plt.figure(figsize=(20,10),dpi=150)
plt.hist([np.array(df1['Polish']),np.array(df1['Symmetry'])],rwidth=1, bins=9)
plt.title("Polish & Symmetry Quality")
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.legend(['Polish','Symmetry','Cut'])
plt.show()

# %%
#Categorical plot for Clarity of diamonds in the data set

plt.figure(figsize=(20,10),dpi=150)
plt.pie(x=df1['Clarity Priority'].value_counts(),labels=ClarityPriority.keys(), autopct='%.2f')
plt.show()

# %%
##Relation plot for Carat Weight Vs Price for GIA and AGSL

sns.set(style = "whitegrid", rc = {'figure.figsize': (12, 10), 'axes.labelsize': 16, 'xtick.labelsize':12, 
                                   'ytick.labelsize':12, 'lines.markersize':10})

sns.relplot(data=df1, x="Carat Weight", y="Price", col = "Polish", hue = "Report", col_wrap = 4)

# %%
sns.set(style = "whitegrid", rc = {'figure.figsize': (12, 20), 'axes.labelsize': 25, 'xtick.labelsize':20, 
                                   'ytick.labelsize':20, 'lines.markersize':10})

for col in cat_columns:
    cat_plot = sns.catplot(x = col, y = "Price", kind = "boxen", height = 7, aspect = 3, data = df1.sort_values(col))

# %%
cat_plot1 = sns.catplot(x = "Color", y = "Price", kind = "violin", height = 7, aspect = 3, data = df1.sort_values(col))

# %%
df3=df1.drop(columns=['Cut','Clarity','Color','Polish','Symmetry','Report'])
cmatrix=df3.corr()
cmatrix
# Out:
#                    Carat Weight     Price  Cut Priority  Color Priority  \
# Carat Weight           1.000000  0.858009      0.075212       -0.114668
# Price                  0.858009  1.000000      0.131367        0.149720
# Cut Priority           0.075212  0.131367      1.000000       -0.029409
# Color Priority        -0.114668  0.149720     -0.029409        1.000000
# Polish Priority        0.068381  0.104888      0.320830       -0.007531
# Clarity Priority       0.096986  0.328192      0.175738        0.026165
# Report Priority       -0.008587 -0.010559      0.268615       -0.101898
# Symmetry Priority      0.063363  0.103754      0.453455       -0.020214
#
#                    Polish Priority  Clarity Priority  Report Priority  \
# Carat Weight              0.068381          0.096986        -0.008587
# Price                     0.104888          0.328192        -0.010559
# Cut Priority              0.320830          0.175738         0.268615
# ...

# %%
#Correlation between various charactristics of diamond  -> 
plt.figure(figsize=(10,8),dpi=200) 
sns.set(font_scale=1)
sns.set
sns.heatmap(cmatrix,annot=True, linewidth=0.40,cmap='RdYlBu')
# Out:
# <AxesSubplot:>

# %%
df4=df1.drop(columns=['Cut Priority','Clarity Priority','Color Priority','Polish Priority','Symmetry Priority'])
cmatrix4=df4.corr()
cmatrix4
#Correlation between various charactristics of diamond  -> 
plt.figure(figsize=(10,8),dpi=200) 
sns.set(font_scale=1)
sns.set
sns.heatmap(cmatrix4,annot=True, linewidth=0.40,cmap='RdYlBu')
# Out:
# <AxesSubplot:>
